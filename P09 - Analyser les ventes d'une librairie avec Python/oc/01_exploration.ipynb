# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../sources')
import data_manager as data

# %%
dir_path = "../data/"

df_clients = pd.read_csv(r"..\data\raw\customers.csv", sep=';')
df_produits = pd.read_csv(r"..\data\raw\products.csv", sep=';')
df_ventes = pd.read_csv(r"..\data\raw\Transactions.csv", sep=';')
# Out:
# C:\Users\trist\AppData\Local\Temp\ipykernel_27572\1072858710.py:5: DtypeWarning: Columns (0,1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ventes = pd.read_csv(r"..\data\raw\Transactions.csv", sep=';')

# %% [markdown]
# ### Exploration

# %%
data.inspecteur_gadget(df_clients)
# Out:
# -- 8621 lignes | 3 colonnes | 0 lignes doublons --
# --------------------------------------------------
#              Type  Manquants Manquants %  Uniques
# client_id  object          0        0.0%     8621
# sex        object          0        0.0%        2
# birth       int64          0        0.0%       76
# --------------------------------------------------
# Clé potentielle sur client_id

# %%
data.inspecteur_gadget(df_produits)
# Out:
# -- 3286 lignes | 3 colonnes | 0 lignes doublons --
# --------------------------------------------------
#             Type  Manquants Manquants %  Uniques
# id_prod   object          0        0.0%     3286
# price    float64          0        0.0%     1454
# categ      int64          0        0.0%        3
# --------------------------------------------------
# Clé potentielle sur id_prod

# %%
df_ventes = df_ventes.dropna(how='all')
data.inspecteur_gadget(df_ventes.dropna())
# Out:
# -- 687534 lignes | 4 colonnes | 0 lignes doublons --
# --------------------------------------------------
#               Type  Manquants Manquants %  Uniques
# id_prod     object          0        0.0%     3265
# date        object          0        0.0%   687419
# session_id  object          0        0.0%   345505
# client_id   object          0        0.0%     8600
# --------------------------------------------------
# Pas de colonne éligible en PK

# %% [markdown]
# ### Jonctions

# %%
df_inter = df_clients.merge(df_ventes, on='client_id', how='inner')
df = df_inter.merge(df_produits, on='id_prod', how='inner')

# %% [markdown]
# ### Features

# %%
# identification des clients BtoB
ca_par_clients = df.groupby('client_id')['price'].sum().sort_values(ascending=False).reset_index()
ca_par_clients['segment'] = np.where(ca_par_clients['price'] > 50000, 'BtoB', 'BtoC')
df['segment'] = df['client_id'].map(ca_par_clients.set_index('client_id')['segment'])

# %%
# age des clients
df['date'] = pd.to_datetime(df['date'])
df['age'] = df['date'].dt.year - df['birth']

# %%
df
# Out:
#        client_id sex  birth id_prod                       date session_id  \
# 0         c_4410   f   1967   1_483 2021-03-13 21:35:55.949042     s_5913
# 1         c_4410   f   1967  0_1111 2021-03-22 01:27:49.480137     s_9707
# 2         c_4410   f   1967   1_385 2021-03-22 01:40:22.782925     s_9707
# 3         c_4410   f   1967  0_1455 2021-03-22 14:29:25.189266     s_9942
# 4         c_4410   f   1967  0_1420 2021-03-22 22:31:25.825764    s_10092
# ...          ...  ..    ...     ...                        ...        ...
# 687529      c_84   f   1982  0_1472 2022-05-14 00:24:49.391917   s_208110
# 687530      c_84   f   1982  0_1438 2022-05-29 06:11:50.316631   s_215697
# 687531      c_84   f   1982   1_459 2022-12-17 00:16:56.629536   s_313173
# 687532      c_84   f   1982  0_1104 2022-12-17 00:24:14.357525   s_313173
# 687533      c_84   f   1982   1_688 2022-12-17 00:36:24.148027   s_313173
#
#         price  categ segment  age
# 0       15.99      1    BtoC   54
# ...

# %%
df.to_csv(r"..\data\processed\final.csv")
