# %%
import pandas as pd
import numpy as np
from tools import sherlock

# %%
df = pd.read_csv(r"..\data\raw\2BLONDEL_2024.csv", sep=';', encoding='latin_1', decimal=',')

# %% [markdown]
# # Exploration

# %%
sherlock(df)
# Out:
# 706 lignes | 16 colonnes | 0 lignes doublons
# --------------------------------------------------
#                      Type  Manquants Manquants %  Uniques
# Code journal          str          0        0.0%        4
# Date écriture         str          0        0.0%      116
# Code compte           str          0        0.0%       46
# Intitulé compte       str          0        0.0%       46
# Pièce                 str          0        0.0%      362
# Libellé écriture      str          0        0.0%      148
# Débit origine     float64          0        0.0%      286
# Crédit origine    float64          0        0.0%      286
# Débit euro        float64          0        0.0%      286
# Crédit euro       float64          0        0.0%      286
# Lettrage              str        631      89.38%        4
# Lettrage n+1          str          0        0.0%        2
# Lettrage partiel      str          0        0.0%        1
# Monnaie               str          0        0.0%        1
# ISO Monnaie       float64        706      100.0%        0
# taux change         int64          0        0.0%        1
# --------------------------------------------------
# Pas de colonne éligible en PK

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_')
df['Date_écriture'] = pd.to_datetime(df['Date_écriture'], format="%d/%m/%Y")
df = df.drop(columns=['Débit_origine', 'Crédit_origine', 'Lettrage_partiel', 'Monnaie', 'ISO_Monnaie', 'taux_change', 'Lettrage', 'Lettrage_n+1'])
df = df.rename(str.lower, axis='columns')
df['année'] = 2024

# %%
sherlock(df)
# Out:
# 706 lignes | 9 colonnes | 0 lignes doublons
# --------------------------------------------------
#                             Type  Manquants Manquants %  Uniques
# code_journal                 str          0        0.0%        4
# date_écriture     datetime64[us]          0        0.0%      116
# code_compte                  str          0        0.0%       46
# intitulé_compte              str          0        0.0%       46
# pièce                        str          0        0.0%      362
# libellé_écriture             str          0        0.0%      148
# débit_euro               float64          0        0.0%      286
# crédit_euro              float64          0        0.0%      286
# année                      int64          0        0.0%        1
# --------------------------------------------------
# Pas de colonne éligible en PK

# %%
df.head()
# Out:
#   code_journal date_écriture code_compte  \
# 0           AC    2024-11-05        FMER
# 1           AC    2024-11-05    62260000
# 2           AC    2024-11-05    62260000
# 3          ACH    2024-05-23    10810000
# 4          ACH    2024-05-23    21810000
#
#                         intitulé_compte             pièce  \
# 0                        AXESCIBLES MER          2411-212
# 1                            Honoraires          2411-212
# 2                            Honoraires          2411-212
# 3                Compte de l'exploitant  2405-ACH -000001
# 4  Installations générales, agencements  2405-ACH -000001
#
#            libellé_écriture  débit_euro  crédit_euro  année
# 0  Honoraire AXESCIBLES MER         0.0        960.0   2024
# 1  Honoraire AXESCIBLES MER       800.0          0.0   2024
# 2  Honoraire AXESCIBLES MER       160.0          0.0   2024
# 3                 POINT P P         0.0         54.0   2024
# 4                 POINT P P        54.0          0.0   2024

# %%
# Les codes compte uniques avec leur intitulé
df.groupby(['code_compte', 'intitulé_compte']).size().sort_values(ascending=False).reset_index()
# Out:
#    code_compte                       intitulé_compte    0
# 0     10810000                Compte de l'exploitant  223
# 1     60630000         Entretien et petit équipement  116
# 2     51210000                                Banque   86
# 3     21810000  Installations générales, agencements   84
# 4     70600000                                Loyers   48
# 5     61520000       Entretien sur biens immobiliers   24
# 6     62620000            Frais de télécommunication    9
# 7        FAUCH                                AUCHAN    8
# 8       FCENTR                             CENTRAKOR    8
# 9     61610000                    Primes d'assurance    8
# 10     FACTION                                ACTION    6
# 11     FORANGE                                ORANGE    6
# 12        FNOZ                                   NOZ    6
# 13      FBABOU                                 BABOU    6
# 14       FLECL                               LECLERC    6
# 15    62780000                       Frais bancaires    5
# 16      FBRICO                                 BRICO    4
# 17      FLEROY                          LEROY MERLIN    4
# 18    62310000                             Publicité    3
# 19    62220000                Commissions sur ventes    3
# 20    60611000                                   Eau    3
# 21    16410000                   Prêt 92,5K 05/2039    2
# 22     FMCAFEE                                MCAFEE    2
# 23       FIKEA                                  IKEA    2
# 24       FCORA                                  CORA    2
# 25        FEAU                     SYNDICAT DES EAUX    2
# 26    62270000       Frais d'actes et de contentieux    2
# 27    21310000                             Bâtiments    2
# 28    62260000                            Honoraires    2
# 29    68112000            Dot.amts immos corporelles    2
# 30        FMER                        AXESCIBLES MER    2
# 31      FJARDI                             JARDILAND    2
# 32        FSOS                        SOS ACCESSOIRE    2
# 33      FCONFO                             CONFORAMA    2
# 34        FCGA                                CGAVAC    2
# 35      FCARRE                             CARREFOUR    2
# 36    21100000                              Terrains    1
# 37    28131000                      Amort. bâtiments    1
# 38    61560000                           Maintenance    1
# 39    28181000             Amort. aménagement divers    1
# 40    41810000                    Factures à Etablir    1
# 41    62810000                           Cotisations    1
# 42    66116000        Charges d'intérêts sur emprunt    1
# 43    63512000                       Taxes foncières    1
# 44    62510000               Voyages et déplacements    1
# 45        FBUT                                   BUT    1

# %%
# Répartition par journal
df.groupby('code_journal').size()
# Out:
# code_journal
# AC       3
# ACH    482
# BQ     192
# OD      29
# dtype: int64

# %%
df.query("code_journal == 'AC'")
# Out:
#   code_journal date_écriture code_compte intitulé_compte     pièce  \
# 0           AC    2024-11-05        FMER  AXESCIBLES MER  2411-212
# 1           AC    2024-11-05    62260000      Honoraires  2411-212
# 2           AC    2024-11-05    62260000      Honoraires  2411-212
#
#            libellé_écriture  débit_euro  crédit_euro  année
# 0  Honoraire AXESCIBLES MER         0.0        960.0   2024
# 1  Honoraire AXESCIBLES MER       800.0          0.0   2024
# 2  Honoraire AXESCIBLES MER       160.0          0.0   2024

# %%
# Quelques lignes par journal pour voir les patterns
df.query("code_journal == 'BQ'").head(10)
# Out:
#     code_journal date_écriture code_compte intitulé_compte             pièce  \
# 485           BQ    2024-07-18    70600000          Loyers  2407-BQ  -000001
# 486           BQ    2024-07-18    51210000          Banque  2407-BQ  -000001
# 487           BQ    2024-07-19    70600000          Loyers  2407-BQ  -000002
# 488           BQ    2024-07-19    51210000          Banque  2407-BQ  -000002
# 489           BQ    2024-07-24       FAUCH          AUCHAN  2407-BQ  -000003
# 490           BQ    2024-07-24    51210000          Banque  2407-BQ  -000003
# 491           BQ    2024-07-24    70600000          Loyers  2407-BQ  -000004
# 492           BQ    2024-07-24    51210000          Banque  2407-BQ  -000004
# 493           BQ    2024-07-29    70600000          Loyers  2407-BQ  -000005
# 494           BQ    2024-07-29    51210000          Banque  2407-BQ  -000005
#
#     libellé_écriture  débit_euro  crédit_euro  année
# 485     FACTURE HOTE        0.00       174.48   2024
# 486     FACTURE HOTE      174.48         0.00   2024
# 487          AIR BNB        0.00         0.01   2024
# 488          AIR BNB        0.01         0.00   2024
# 489           AUCHAN       42.99         0.00   2024
# 490           AUCHAN        0.00        42.99   2024
# 491          AIR BNB        0.00       546.59   2024
# 492          AIR BNB      546.59         0.00   2024
# 493          AIR BNB        0.00       214.97   2024
# 494          AIR BNB      214.97         0.00   2024
